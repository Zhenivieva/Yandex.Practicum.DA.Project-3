# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель исследования**
# Изучить архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет и установить параметры., определяющие рыночную стоимость объектов недвижимости.
#
# **Ход исследования**
#
# Данные сервиса Яндекс.Недвижимость получим из файла `real_estate_data.csv`. О качестве данных ничего не известно. Поэтому перед проведением анализа понадобится обзор и предобработка данных. Удалим ошибки и дубликаты в данных, а также редкие и выбивающиеся значения.
#
# Таким образом, исследование пройдёт в четыре этапа:
#  1. Обзор данных.
#  2. Предобработка данных.
#  3. Добавление необходимых столбцов в таблицу.
#  4. Исследовательский анализ данных.

# %% [markdown]
# ### Откроем файл с данными и изучим общую информацию.

# %% [markdown]
# 1.1. Импортируем библиотеку pandas. Считаем данные из csv-файла в датафрейм и сохраним в переменную data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# 1.2. Выведем первые 20 строчек датафрейма data на экран:

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 13            20   3550000.0       42.80  2017-07-01T00:00:00      2
# 14             1   4400000.0       36.00  2016-06-23T00:00:00      1
# 15            16   4650000.0       39.00  2017-11-18T00:00:00      1
# 16            11   6700000.0       82.00  2017-11-23T00:00:00      3
# 17             6   4180000.0       36.00  2016-09-09T00:00:00      1
# 18             8   3250000.0       31.00  2017-01-27T00:00:00      1
# 19            16  14200000.0      121.00  2019-01-09T00:00:00      3
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0        51.00      8          NaN  ...
# 1              NaN          11.0        18.60      1          NaN  ...
# 2              NaN           5.0        34.30      4          NaN  ...
# 3              NaN          14.0          NaN      9          NaN  ...
# 4             3.03          14.0        32.00     13          NaN  ...
# 5              NaN          12.0        14.40      5          NaN  ...
# 6              NaN          26.0        10.60      6          NaN  ...
# 7              NaN          24.0          NaN     22          NaN  ...
# 8              NaN          27.0        15.43     26          NaN  ...
# 9             2.50           9.0        43.60      7          NaN  ...
# 10            2.67          12.0        20.30      3          NaN  ...
# 11             NaN           5.0        31.00      4        False  ...
# 12             NaN           5.0        30.00      5          NaN  ...
# 13            2.56           5.0        27.00      5          NaN  ...
# 14             NaN           6.0        17.00      1          NaN  ...
# 15             NaN          14.0        20.50      5          NaN  ...
# 16            3.05           5.0        55.60      1          NaN  ...
# 17             NaN          17.0        16.50      7          NaN  ...
# 18            2.50           5.0        19.40      2          NaN  ...
# 19            2.75          16.0        76.00      8          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# 0          25.00      NaN            Санкт-Петербург           18863.0
# 1          11.00      2.0             посёлок Шушары           12817.0
# 2           8.30      0.0            Санкт-Петербург           21741.0
# 3            NaN      0.0            Санкт-Петербург           28098.0
# 4          41.00      NaN            Санкт-Петербург           31856.0
# 5           9.10      NaN  городской посёлок Янино-1               NaN
# 6          14.40      1.0          посёлок Парголово           52996.0
# 7          18.90      2.0            Санкт-Петербург           23982.0
# 8           8.81      NaN             посёлок Мурино               NaN
# 9           6.50      2.0            Санкт-Петербург           50898.0
# 10          8.50      NaN            Санкт-Петербург           38357.0
# 11          6.00      1.0                  Ломоносов           48252.0
# 12          9.00      0.0                  Сертолово               NaN
# 13          5.20      1.0                   Петергоф           37868.0
# 14          8.00      0.0                     Пушкин           20782.0
# 15          7.60      1.0            Санкт-Петербург           12900.0
# 16          9.00      NaN            Санкт-Петербург           22108.0
# 17         11.00      1.0            Санкт-Петербург           33564.0
# 18          5.60      1.0            Санкт-Петербург           44060.0
# 19         12.00      NaN            Санкт-Петербург           38900.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1              18603.0               0.0            NaN               0.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 4               8098.0               2.0          112.0               1.0
# 5                  NaN               NaN            NaN               NaN
# 6              19143.0               0.0            NaN               0.0
# 7              11634.0               0.0            NaN               0.0
# 8                  NaN               NaN            NaN               NaN
# 9              15008.0               0.0            NaN               0.0
# 10             13878.0               1.0          310.0               2.0
# 11             51677.0               0.0            NaN               0.0
# 12                 NaN               NaN            NaN               NaN
# 13             33058.0               1.0          294.0               3.0
# 14             30759.0               0.0            NaN               1.0
# 15             14259.0               1.0          590.0               1.0
# 16             10698.0               3.0          420.0               0.0
# 17             14616.0               0.0            NaN               1.0
# 18             10842.0               1.0          759.0               0.0
# 19             12843.0               0.0            NaN               0.0
#
#     ponds_nearest  days_exposition
# 0           755.0              NaN
# 1             NaN             81.0
# 2           574.0            558.0
# 3           234.0            424.0
# 4            48.0            121.0
# 5             NaN             55.0
# 6             NaN            155.0
# 7             NaN              NaN
# 8             NaN            189.0
# 9             NaN            289.0
# 10          553.0            137.0
# 11            NaN              7.0
# 12            NaN             90.0
# 13          298.0            366.0
# 14           96.0            203.0
# 15          296.0             19.0
# 16            NaN            397.0
# 17          859.0            571.0
# 18            NaN            168.0
# 19            NaN             97.0
#
# [20 rows x 22 columns]

# %% [markdown]
# 1.3. Выведем основную информацию о датафрейме с помощью метода info():

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# 1.4. Построим общую гистограмму для всех столбцов таблицы:

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка пропусков

# %% [markdown]
# ##### Найдем и изучим пропущенные значения в столбцах:

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Из результатов видно, что пропуски имеются в столбцах: `ceiling_height`, `floors_total`, `living_area`,
# `is_apartment`, `kitchen_area`, `balcony`, `locality_name`, `airports_nearest`, `cityCenters_nearest`,
# `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest`, `days_exposition`.

# %% [markdown]
# ##### Построим температурный график по количеству пропусков:

# %%
pd.DataFrame(data.isna().mean().to_frame(name='Пропуски').query('Пропуски > 0')['Пропуски'])\
            .style.background_gradient('coolwarm')\
            .format({'Пропуски':'{:.0%}'})
# Out:
# <style type="text/css">
# #T_cab42_row0_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_cab42_row1_col0, #T_cab42_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cab42_row2_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_cab42_row3_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cab42_row4_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_cab42_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_cab42_row7_col0, #T_cab42_row8_col0, #T_cab42_row9_col0, #T_cab42_row11_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_cab42_row10_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_cab42_row12_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_cab42_row13_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cab42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cab42_level0_col0" class="col_heading level0 col0" >Пропуски</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cab42_level0_row0" class="row_heading level0 row0" >ceiling_height</th>
#       <td id="T_cab42_row0_col0" class="data row0 col0" >39%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row1" class="row_heading level0 row1" >floors_total</th>
#       <td id="T_cab42_row1_col0" class="data row1 col0" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row2" class="row_heading level0 row2" >living_area</th>
#       <td id="T_cab42_row2_col0" class="data row2 col0" >8%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row3" class="row_heading level0 row3" >is_apartment</th>
#       <td id="T_cab42_row3_col0" class="data row3 col0" >88%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row4" class="row_heading level0 row4" >kitchen_area</th>
#       <td id="T_cab42_row4_col0" class="data row4 col0" >10%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row5" class="row_heading level0 row5" >balcony</th>
#       <td id="T_cab42_row5_col0" class="data row5 col0" >49%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row6" class="row_heading level0 row6" >locality_name</th>
#       <td id="T_cab42_row6_col0" class="data row6 col0" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row7" class="row_heading level0 row7" >airports_nearest</th>
#       <td id="T_cab42_row7_col0" class="data row7 col0" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row8" class="row_heading level0 row8" >cityCenters_nearest</th>
#       <td id="T_cab42_row8_col0" class="data row8 col0" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row9" class="row_heading level0 row9" >parks_around3000</th>
#       <td id="T_cab42_row9_col0" class="data row9 col0" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row10" class="row_heading level0 row10" >parks_nearest</th>
#       <td id="T_cab42_row10_col0" class="data row10 col0" >66%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row11" class="row_heading level0 row11" >ponds_around3000</th>
#       <td id="T_cab42_row11_col0" class="data row11 col0" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row12" class="row_heading level0 row12" >ponds_nearest</th>
#       <td id="T_cab42_row12_col0" class="data row12 col0" >62%</td>
#     </tr>
#     <tr>
#       <th id="T_cab42_level0_row13" class="row_heading level0 row13" >days_exposition</th>
#       <td id="T_cab42_row13_col0" class="data row13 col0" >13%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Возможные причины появления пропусков в исходных данных:

# %% [markdown]
# Изучим по-подробнее состав данных в столбцах is_apartment и balcony:

# %%
data['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64

# %%
data['balcony'].value_counts(dropna=False)
# Out:
# NaN    11519
# 1.0     4195
# 0.0     3758
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Возможные причины появления пропусков в исходных данных:
# Проанализировав строки с пропусками, сделали следующие предположения: пропуски в столбце `is_apartment`, вероятно, связаны с тем, что данные объекты недвижимости не являются апартаментами, такие пропуски можно заменить на `False`. Пропуски в графе `balcony`, вероятно, связаны с тем, что в данных объектах недвижимости нет балконов, их можно заменить нулями.
# Существенное число пропусков говорит о том, что они неслучайны и могли возникнуть по причине неполного заполнения данных пользователями, ошибки на этапе выгрузки данных, либо в результате неправильного запроса/объединения таблиц.

# %% [markdown]
# ##### Заменим пропуски в столбцах `is_apartment` и `balcony`:

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['is_apartment'].value_counts(dropna=False)
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %%
data['balcony'] = data['balcony'].fillna(0)
data['balcony'].value_counts(dropna=False)
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# ##### Заменим пропуски в столбце  `living_area`, произведениями известных величин общей площади на коэффициенты долей жилой площади в общей в зависимости от количества комнат:

# %%
data.query('living_area > 0.9 * total_area')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 440               8    2480000.0       27.11  2018-03-12T00:00:00      0
# 551               8    3100000.0       31.59  2018-03-08T00:00:00      1
# 1854              3    6540000.0       60.20  2018-10-14T00:00:00      2
# 1992              5    4000000.0       37.40  2018-02-11T00:00:00      1
# 2950              5    3050000.0       35.00  2017-09-26T00:00:00      2
# 2959              9    2550000.0       32.00  2017-12-02T00:00:00      1
# 3891              4    2600000.0       70.40  2017-07-29T00:00:00      3
# 4339             19    6900000.0       72.00  2019-03-25T00:00:00      3
# 6802             15    7500000.0       69.00  2017-02-15T00:00:00      2
# 7398              6    6297880.0       83.66  2018-10-23T00:00:00      3
# 7415              0    6500000.0       67.00  2017-06-17T00:00:00      2
# 7857             11  150000000.0      230.00  2017-10-25T00:00:00      8
# 8683             10    3500000.0       32.50  2016-05-05T00:00:00      1
# 9138             17    2920000.0       23.29  2018-12-12T00:00:00      1
# 9861             10    2350000.0       25.00  2017-12-03T00:00:00      0
# 10606            14    2950000.0       25.27  2017-11-17T00:00:00      0
# 10696            17    3690000.0       45.00  2018-03-06T00:00:00      3
# 10913             7    3000000.0       43.30  2019-04-29T00:00:00      1
# 11313             2    3247000.0       37.00  2017-10-22T00:00:00      1
# 12412             0    3300000.0       27.00  2017-08-15T00:00:00      0
# 12530            20    4400000.0       39.03  2019-04-21T00:00:00      1
# 12691             1    3700000.0       24.20  2017-11-10T00:00:00      0
# 15513             3    3500000.0       33.82  2014-12-26T00:00:00      1
# 16606             8    6695000.0       58.00  2018-10-11T00:00:00      2
# 17151            12    5840000.0       58.50  2018-10-16T00:00:00      3
# 18455            17    3290000.0       32.00  2018-08-08T00:00:00      1
# 19268            10    3450000.0       43.30  2018-09-18T00:00:00      1
# 20256             5   13351000.0      102.70  2018-07-03T00:00:00      6
# 21227             0    8200000.0       71.00  2017-07-21T00:00:00      0
# 21519             8    3950000.0       55.00  2018-10-28T00:00:00      2
# 21676            20   23600000.0      181.30  2017-07-10T00:00:00      4
# 21956             0    5200000.0       46.00  2018-07-20T00:00:00      2
# 22095             6    2194000.0       36.50  2017-09-27T00:00:00      1
# 23202            13    4919880.0       67.92  2018-10-23T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 440               NaN          17.0        24.75      4         False  ...
# 551              2.70          19.0        30.55      2         False  ...
# 1854              NaN          24.0        55.00     24         False  ...
# 1992             2.53          16.0        36.40     10         False  ...
# 2950              NaN           5.0        33.00      3         False  ...
# 2959              NaN          14.0        30.20     13         False  ...
# 3891             2.50           5.0        68.10      5         False  ...
# 4339             3.50           4.0        70.00      1          True  ...
# 6802             4.50           3.0        64.00      3         False  ...
# 7398              NaN           3.0        77.00      2         False  ...
# 7415              NaN          18.0        63.00     18         False  ...
# 7857              NaN           8.0       220.00      8         False  ...
# 8683             3.00          23.0        29.90     11         False  ...
# 9138              NaN           3.0        21.00      1         False  ...
# 9861              NaN          22.0        25.00     17         False  ...
# 10606             NaN          25.0        25.00     11         False  ...
# 10696            2.50           5.0        42.00      5         False  ...
# 10913            2.80           9.0        40.70      3         False  ...
# 11313             NaN          25.0        35.00      8         False  ...
# 12412             NaN          25.0        25.00     22         False  ...
# 12530            2.75           7.0        36.90      7         False  ...
# 12691             NaN          19.0        24.20     13         False  ...
# 15513             NaN          27.0        33.00     15         False  ...
# 16606             NaN           6.0        54.00      6         False  ...
# 17151            2.70          10.0        54.50      8         False  ...
# 18455            2.70           5.0        30.00      5         False  ...
# 19268            2.75          18.0        41.30      7         False  ...
# 20256            3.40           4.0       101.00      1         False  ...
# 21227            5.80           5.0        68.00      5         False  ...
# 21519            2.60           5.0        52.50      1         False  ...
# 21676            3.50           7.0       164.70      7         False  ...
# 21956             NaN           5.0        44.00      5         False  ...
# 22095             NaN           3.0        33.20      3         False  ...
# 23202             NaN           3.0        63.00      3         False  ...
#
#        kitchen_area  balcony                locality_name  airports_nearest  \
# 440             NaN      2.0              Санкт-Петербург           38171.0
# 551            9.28      2.0               посёлок Мурино               NaN
# 1854          14.84      0.0              Санкт-Петербург           33606.0
# 1992           8.60      1.0              Санкт-Петербург           19979.0
# 2950           8.50      0.0                      Гатчина               NaN
# 2959            NaN      1.0              деревня Кудрово               NaN
# 3891           9.00      3.0                       Любань               NaN
# 4339            NaN      0.0              Санкт-Петербург           31487.0
# 6802          25.00      0.0              Санкт-Петербург           40326.0
# 7398          12.39      0.0                   Всеволожск               NaN
# 7415            NaN      0.0              Санкт-Петербург           18428.0
# 7857            NaN      0.0              Санкт-Петербург           25525.0
# 8683            NaN      2.0              Санкт-Петербург           34967.0
# 9138           2.00      0.0              Санкт-Петербург           19506.0
# 9861            NaN      2.0               посёлок Мурино               NaN
# 10606           NaN      1.0              Санкт-Петербург           11405.0
# 10696          5.30      0.0              Санкт-Петербург           11459.0
# 10913         12.30      1.0               деревня Старая               NaN
# 11313         16.00      0.0              Санкт-Петербург           18053.0
# 12412           NaN      0.0              Санкт-Петербург           12199.0
# 12530         18.60      2.0  городской посёлок Новоселье               NaN
# 12691           NaN      1.0              Санкт-Петербург           17837.0
# 15513          9.32      2.0            посёлок Парголово           52726.0
# 16606           NaN      0.0              Санкт-Петербург           31877.0
# 17151          7.10      1.0              Санкт-Петербург           26190.0
# 18455          8.20      2.0                   Всеволожск               NaN
# 19268           NaN      2.0               посёлок Мурино               NaN
# 20256           NaN      0.0              Санкт-Петербург           24477.0
# 21227           NaN      0.0              Санкт-Петербург           20170.0
# 21519          9.00      2.0                      Гатчина               NaN
# 21676         10.70      1.0              Санкт-Петербург           26902.0
# 21956          8.00      1.0              Санкт-Петербург           14103.0
# 22095           NaN      0.0              Санкт-Петербург           39446.0
# 23202         13.04      0.0                   Всеволожск               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 440               15015.0               0.0            NaN               2.0
# 551                   NaN               NaN            NaN               NaN
# 1854              14769.0               0.0            NaN               0.0
# 1992              21690.0               0.0            NaN               1.0
# 2950                  NaN               NaN            NaN               NaN
# 2959                  NaN               NaN            NaN               NaN
# 3891                  NaN               NaN            NaN               NaN
# 4339               4466.0               2.0          353.0               1.0
# 6802              15610.0               0.0            NaN               2.0
# 7398                  NaN               NaN            NaN               NaN
# 7415              16134.0               1.0          739.0               1.0
# 7857               5845.0               2.0          116.0               0.0
# 8683              14640.0               0.0            NaN               1.0
# 9138               4008.0               0.0            NaN               2.0
# 9861                  NaN               NaN            NaN               NaN
# 10606             13222.0               0.0            NaN               1.0
# 10696             15824.0               0.0            NaN               1.0
# 10913                 NaN               NaN            NaN               NaN
# 11313             16077.0               0.0            NaN               0.0
# 12412             12111.0               0.0            NaN               1.0
# 12530                 NaN               NaN            NaN               NaN
# 12691             16840.0               0.0            NaN               2.0
# 15513             18900.0               0.0            NaN               0.0
# 16606              5347.0               2.0          231.0               3.0
# 17151             13893.0               0.0            NaN               0.0
# 18455                 NaN               NaN            NaN               NaN
# 19268                 NaN               NaN            NaN               NaN
# 20256              5464.0               2.0          519.0               0.0
# 21227              1261.0               2.0          295.0               3.0
# 21519                 NaN               NaN            NaN               NaN
# 21676              5605.0               3.0          484.0               1.0
# 21956             15182.0               1.0          488.0               0.0
# 22095             18500.0               0.0            NaN               2.0
# 23202                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 440            982.0             64.0
# 551              NaN             70.0
# 1854             NaN             60.0
# 1992          1052.0             74.0
# 2950             NaN             45.0
# 2959             NaN            157.0
# 3891             NaN             45.0
# 4339           439.0             22.0
# 6802           852.0            427.0
# 7398             NaN             60.0
# 7415           758.0            298.0
# 7857             NaN            135.0
# 8683           564.0             45.0
# 9138            45.0            107.0
# 9861             NaN             13.0
# 10606          623.0             51.0
# 10696          493.0              7.0
# 10913            NaN              NaN
# 11313            NaN            155.0
# 12412          337.0            161.0
# 12530            NaN              NaN
# 12691          210.0             74.0
# 15513            NaN            940.0
# 16606          537.0             42.0
# 17151            NaN              NaN
# 18455            NaN             88.0
# 19268            NaN             44.0
# 20256            NaN            229.0
# 21227          366.0             30.0
# 21519            NaN             58.0
# 21676          305.0              NaN
# 21956            NaN              7.0
# 22095          639.0             36.0
# 23202            NaN             60.0
#
# [34 rows x 22 columns]

# %%
data['living_area'] = data['living_area'].fillna(data['total_area'] *
                                                 (data.groupby('rooms')['living_area'].transform('median') /
                                                 data.groupby('rooms')['total_area'].transform('median')))

# %% [markdown]
# Проверим отсутствие пропусков:

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Заполним пропуски в столбце kitchen_area:

# %% [markdown]
# Рассчитаем недостающие площади кухонь из условия, что сумма площади кухни и жилой площади не должна превышать 0,9 от общей площади
# total_area * 0.9 >= (living_area + kitchen_area):

# %%
data['kitchen_area_from_condition'] = data['total_area'] * 0.9 - data['living_area']
data.loc[data['kitchen_area_from_condition'] < 0, 'kitchen_area_from_condition'] =  0
data['kitchen_area_from_condition'].describe()
# Out:
# count    23699.000000
# mean        19.679950
# std         12.836160
# min          0.000000
# 25%         12.850503
# 50%         17.037736
# 75%         22.530000
# max        400.300000
# Name: kitchen_area_from_condition, dtype: float64

# %% [markdown]
# Рассчитаем недостающие площади кухонь как произведения известных величин общей площади на коэффициент доли площади кухни в общей площади:

# %%
data['kitchen_area_from_ratio'] = data['kitchen_area'].fillna(data['total_area'] * 
                                                 (data['kitchen_area'].median() / data['total_area'].median()))

# %% [markdown]
# Заполним пропуски в этом столбце минимальными значениями из них:

# %% [markdown]
# data['kitchen_area'] = data['kitchen_area_from_condition'] if data['kitchen_area_from_condition'] < \
# data['kitchen_area_from_ratio'] else data['kitchen_area_from_ratio']

# %%
data['kitchen_area'] = data[['kitchen_area_from_condition','kitchen_area_from_ratio']].min(axis=1)

# %% [markdown]
# Проверим отсутствие пропусков:

# %%
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Проверим выполнение условия суммы площадей:

# %%
len(data.query('total_area * 0.9 < (living_area + kitchen_area)'))
# Out:
# 34

# %% [markdown]
# ##### Пропуски в столбце `'locality_name'` и `floors_total` составляют малую часть данных, и их можно отбросить:

# %%
data = data.dropna(subset = ['locality_name', 'floors_total'])

# %% [markdown]
# ##### Логичную замену в осталных столбцах предложить невозможно, поэтому на данном этапе оставим эти значения пустыми. Посмотрим на оставшееся количество пропусков:

# %%
data.isna().sum()
# Out:
# total_images                       0
# last_price                         0
# total_area                         0
# first_day_exposition               0
# rooms                              0
# ceiling_height                  9084
# floors_total                       0
# living_area                        0
# floor                              0
# is_apartment                       0
# studio                             0
# open_plan                          0
# kitchen_area                       0
# balcony                            0
# locality_name                      0
# airports_nearest                5524
# cityCenters_nearest             5501
# parks_around3000                5500
# parks_nearest                  15535
# ponds_around3000                5500
# ponds_nearest                  14529
# days_exposition                 3171
# kitchen_area_from_condition        0
# kitchen_area_from_ratio            0
# dtype: int64

# %% [markdown]
# #### Типы данных в каждом столбце

# %% [markdown]
# ##### Найдем столбцы, в которых нужно изменить тип данных:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_images                 23565 non-null  int64
#  1   last_price                   23565 non-null  float64
#  2   total_area                   23565 non-null  float64
#  3   first_day_exposition         23565 non-null  object
#  4   rooms                        23565 non-null  int64
#  5   ceiling_height               14481 non-null  float64
#  6   floors_total                 23565 non-null  float64
#  7   living_area                  23565 non-null  float64
#  8   floor                        23565 non-null  int64
#  9   is_apartment                 23565 non-null  bool
#  10  studio                       23565 non-null  bool
#  11  open_plan                    23565 non-null  bool
#  12  kitchen_area                 23565 non-null  float64
#  13  balcony                      23565 non-null  float64
#  14  locality_name                23565 non-null  object
#  15  airports_nearest             18041 non-null  float64
#  16  cityCenters_nearest          18064 non-null  float64
#  17  parks_around3000             18065 non-null  float64
#  18  parks_nearest                8030 non-null   float64
#  19  ponds_around3000             18065 non-null  float64
#  20  ponds_nearest                9036 non-null   float64
#  21  days_exposition              20394 non-null  float64
#  22  kitchen_area_from_condition  23565 non-null  float64
#  23  kitchen_area_from_ratio      23565 non-null  float64
# dtypes: bool(3), float64(16), int64(3), object(2)
# memory usage: 4.0+ MB

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1             NaN          11.0    18.600000      1         False  ...
# 2             NaN           5.0    34.300000      4         False  ...
# 3             NaN          14.0    98.013699      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#      locality_name  airports_nearest  cityCenters_nearest  parks_around3000  \
# 0  Санкт-Петербург           18863.0              16028.0               1.0
# 1   посёлок Шушары           12817.0              18603.0               0.0
# 2  Санкт-Петербург           21741.0              13933.0               1.0
# 3  Санкт-Петербург           28098.0               6800.0               2.0
# 4  Санкт-Петербург           31856.0               8098.0               2.0
#
#   parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 0         482.0               2.0          755.0              NaN
# 1           NaN               0.0            NaN             81.0
# 2          90.0               2.0          574.0            558.0
# 3          84.0               3.0          234.0            424.0
# 4         112.0               1.0           48.0            121.0
#
#    kitchen_area_from_condition  kitchen_area_from_ratio
# 0                    46.200000                   25.000
# 1                    17.760000                   11.000
# 2                    16.100000                    8.300
# 3                    45.086301                   27.825
# 4                    58.000000                   41.000
#
# [5 rows x 24 columns]

# %% [markdown]
# Очевидно, что данные в столбце `first_day_exposition` должны иметь тип datetime64, т.к. это дата и правильный формат может пригодиться для дальнейших вычислений, а в столбцах `floors_total`, `balcony`,
# `parks_around3000`, `ponds_around3000`, `days_exposition` - int64, т.к. это всегда целые числа. Данные столбца `last_price` также логично заменить на тип int64, т.к. цены на объекты недвижимости всегда являются целыми числами.

# %% [markdown]
# ##### Выполним соответствующие преобразования:

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data['floors_total'] = data['floors_total'].astype('int')
data['balcony'] = data['balcony'].astype('int')
data['last_price'] = data['last_price'].astype('int')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_images                 23565 non-null  int64
#  1   last_price                   23565 non-null  int64
#  2   total_area                   23565 non-null  float64
#  3   first_day_exposition         23565 non-null  datetime64[ns]
#  4   rooms                        23565 non-null  int64
#  5   ceiling_height               14481 non-null  float64
#  6   floors_total                 23565 non-null  int64
#  7   living_area                  23565 non-null  float64
#  8   floor                        23565 non-null  int64
#  9   is_apartment                 23565 non-null  bool
#  10  studio                       23565 non-null  bool
#  11  open_plan                    23565 non-null  bool
#  12  kitchen_area                 23565 non-null  float64
#  13  balcony                      23565 non-null  int64
#  14  locality_name                23565 non-null  object
#  15  airports_nearest             18041 non-null  float64
#  16  cityCenters_nearest          18064 non-null  float64
#  17  parks_around3000             18065 non-null  float64
#  18  parks_nearest                8030 non-null   float64
#  19  ponds_around3000             18065 non-null  float64
#  20  ponds_nearest                9036 non-null   float64
#  21  days_exposition              20394 non-null  float64
#  22  kitchen_area_from_condition  23565 non-null  float64
#  23  kitchen_area_from_ratio      23565 non-null  float64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(6), object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# Типы данных в столбцах `parks_around3000` и `ponds_around3000` оставили без изменений, т.к. в этих данных присутствует большое количество пропусков, которые нельзя заменить логическими значениями и удалить также нельзя ввиду их числа.

# %% [markdown]
# #### Поиск и удаление дубликатов

# %% [markdown]
# ##### Проверим данные на наличие явных дубликатов:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов на данном этапе не обнаружено.

# %% [markdown]
# ##### Изучим уникальные значения в столбце `locality_name` с названиями населенных пунктов:

# %%
data.locality_name.sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
#        'городской посёлок Свирьстрой', 'городской посёлок Советский',
#        'городской посёлок Фёдоровское', 'городской посёлок Янино-1',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
#        'деревня Вахнова Кара', 'деревня Выскатка', 'деревня Гарболово',
#        'деревня Глинка', 'деревня Горбунки', 'деревня Гостилицы',
#        'деревня Заклинье', 'деревня Заневка', 'деревня Зимитицы',
#        'деревня Извара', 'деревня Иссад', 'деревня Калитино',
#        'деревня Кальтино', 'деревня Камышовка', 'деревня Каськово',
#        'деревня Келози', 'деревня Кипень', 'деревня Кисельня',
#        'деревня Колтуши', 'деревня Коркино', 'деревня Котлы',
#        'деревня Кривко', 'деревня Кудрово', 'деревня Кузьмолово',
#        'деревня Курковицы', 'деревня Куровицы', 'деревня Куттузи',
#        'деревня Лаврики', 'деревня Лаголово', 'деревня Лампово',
#        'деревня Лесколово', 'деревня Лопухинка', 'деревня Лупполово',
#        'деревня Малая Романовка', 'деревня Малое Верево',
#        'деревня Малое Карлино', 'деревня Малые Колпаны',
#        'деревня Мануйлово', 'деревня Меньково', 'деревня Мины',
#        'деревня Мистолово', 'деревня Ненимяки', 'деревня Нижние Осельки',
#        'деревня Нижняя', 'деревня Низино', 'деревня Новое Девяткино',
#        'деревня Новолисино', 'деревня Нурма', 'деревня Оржицы',
#        'деревня Парицы', 'деревня Пельгора', 'деревня Пеники',
#        'деревня Пижма', 'деревня Пикколово', 'деревня Пудомяги',
#        'деревня Пустынка', 'деревня Пчева', 'деревня Рабитицы',
#        'деревня Разбегаево', 'деревня Раздолье', 'деревня Разметелево',
#        'деревня Рапполово', 'деревня Реброво', 'деревня Русско',
#        'деревня Сижно', 'деревня Снегирёвка', 'деревня Старая',
#        'деревня Старая Пустошь', 'деревня Старое Хинколово',
#        'деревня Старополье', 'деревня Старосиверская',
#        'деревня Старые Бегуницы', 'деревня Суоранда',
#        'деревня Сяськелево', 'деревня Тарасово', 'деревня Терпилицы',
#        'деревня Тихковицы', 'деревня Тойворово', 'деревня Торосово',
#        'деревня Торошковичи', 'деревня Трубников Бор',
#        'деревня Фалилеево', 'деревня Фёдоровское', 'деревня Хапо-Ое',
#        'деревня Хязельки', 'деревня Чудской Бор', 'деревня Шпаньково',
#        'деревня Щеглово', 'деревня Юкки', 'деревня Ялгино',
#        'деревня Яльгелево', 'деревня Ям-Тесово',
#        'коттеджный поселок Кивеннапа Север', 'коттеджный поселок Счастье',
#        'коттеджный посёлок Лесное', 'поселок Аннино', 'поселок Барышево',
#        'поселок Бугры', 'поселок Возрождение', 'поселок Войсковицы',
#        'поселок Володарское', 'поселок Гаврилово', 'поселок Гарболово',
#        'поселок Гладкое', 'поселок Глажево', 'поселок Глебычево',
#        'поселок Гончарово', 'поселок Громово', 'поселок Дружноселье',
#        'поселок Елизаветино', 'поселок Жилгородок', 'поселок Жилпосёлок',
#        'поселок Житково', 'поселок Заводской', 'поселок Запорожское',
#        'поселок Зимитицы', 'поселок Ильичёво', 'поселок Калитино',
#        'поселок Каложицы', 'поселок Кингисеппский', 'поселок Кирпичное',
#        'поселок Кобралово', 'поселок Кобринское', 'поселок Коммунары',
#        'поселок Коробицыно', 'поселок Котельский',
#        'поселок Красная Долина', 'поселок Красносельское',
#        'поселок Лесное', 'поселок Лисий Нос', 'поселок Лукаши',
#        'поселок Любань', 'поселок Мельниково', 'поселок Мичуринское',
#        'поселок Молодцово', 'поселок Мурино', 'поселок Новый Свет',
#        'поселок Новый Учхоз', 'поселок Оредеж',
#        'поселок Пансионат Зелёный Бор', 'поселок Первомайское',
#        'поселок Перово', 'поселок Петровское', 'поселок Победа',
#        'поселок Поляны', 'поселок Почап', 'поселок Починок',
#        'поселок Пушное', 'поселок Пчевжа', 'поселок Рабитицы',
#        'поселок Романовка', 'поселок Ромашки', 'поселок Рябово',
#        'поселок Севастьяново', 'поселок Селезнёво', 'поселок Сельцо',
#        'поселок Семиозерье', 'поселок Семрино', 'поселок Серебрянский',
#        'поселок Совхозный', 'поселок Старая Малукса',
#        'поселок Стеклянный', 'поселок Сумино', 'поселок Суходолье',
#        'поселок Тельмана', 'поселок Терволово', 'поселок Торковичи',
#        'поселок Тёсово-4', 'поселок Углово', 'поселок Усть-Луга',
#        'поселок Ушаки', 'поселок Цвелодубово', 'поселок Цвылёво',
#        'поселок городского типа Большая Ижора',
#        'поселок городского типа Вырица',
#        'поселок городского типа Дружная Горка',
#        'поселок городского типа Дубровка',
#        'поселок городского типа Ефимовский',
#        'поселок городского типа Кондратьево',
#        'поселок городского типа Красный Бор',
#        'поселок городского типа Кузьмоловский',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Лесогорский',
#        'поселок городского типа Назия',
#        'поселок городского типа Никольский',
#        'поселок городского типа Приладожский',
#        'поселок городского типа Рахья', 'поселок городского типа Рощино',
#        'поселок городского типа Рябово',
#        'поселок городского типа Синявино',
#        'поселок городского типа Советский',
#        'поселок городского типа Токсово',
#        'поселок городского типа Форносово',
#        'поселок городского типа имени Свердлова',
#        'поселок станции Вещево', 'поселок станции Корнево',
#        'поселок станции Лужайка', 'поселок станции Приветнинское',
#        'посёлок Александровская', 'посёлок Алексеевка', 'посёлок Аннино',
#        'посёлок Белоостров', 'посёлок Бугры', 'посёлок Возрождение',
#        'посёлок Войскорово', 'посёлок Высокоключевой',
#        'посёлок Гаврилово', 'посёлок Дзержинского', 'посёлок Жилгородок',
#        'посёлок Ильичёво', 'посёлок Кикерино', 'посёлок Кобралово',
#        'посёлок Коробицыно', 'посёлок Левашово', 'посёлок Ленинское',
#        'посёлок Лисий Нос', 'посёлок Мельниково', 'посёлок Металлострой',
#        'посёлок Мичуринское', 'посёлок Молодёжное', 'посёлок Мурино',
#        'посёлок Мыза-Ивановка', 'посёлок Новогорелово',
#        'посёлок Новый Свет', 'посёлок Пансионат Зелёный Бор',
#        'посёлок Парголово', 'посёлок Перово', 'посёлок Песочный',
#        'посёлок Петро-Славянка', 'посёлок Петровское',
#        'посёлок Платформа 69-й километр', 'посёлок Плодовое',
#        'посёлок Плоское', 'посёлок Победа', 'посёлок Поляны',
#        'посёлок Понтонный', 'посёлок Пригородный', 'посёлок Пудость',
#        'посёлок Репино', 'посёлок Ропша', 'посёлок Сапёрное',
#        'посёлок Сапёрный', 'посёлок Сосново', 'посёлок Старая Малукса',
#        'посёлок Стеклянный', 'посёлок Стрельна', 'посёлок Суйда',
#        'посёлок Сумино', 'посёлок Тельмана', 'посёлок Терволово',
#        'посёлок Торфяное', 'посёлок Усть-Ижора', 'посёлок Усть-Луга',
#        'посёлок Форт Красная Горка', 'посёлок Шугозеро', 'посёлок Шушары',
#        'посёлок Щеглово', 'посёлок городского типа Важины',
#        'посёлок городского типа Вознесенье',
#        'посёлок городского типа Вырица',
#        'посёлок городского типа Красный Бор',
#        'посёлок городского типа Кузнечное',
#        'посёлок городского типа Кузьмоловский',
#        'посёлок городского типа Лебяжье', 'посёлок городского типа Мга',
#        'посёлок городского типа Павлово',
#        'посёлок городского типа Рощино', 'посёлок городского типа Рябово',
#        'посёлок городского типа Сиверский',
#        'посёлок городского типа Тайцы', 'посёлок городского типа Токсово',
#        'посёлок городского типа Ульяновка',
#        'посёлок городского типа Форносово',
#        'посёлок городского типа имени Морозова',
#        'посёлок городского типа имени Свердлова',
#        'посёлок при железнодорожной станции Вещево',
#        'посёлок при железнодорожной станции Приветнинское',
#        'посёлок станции Громово', 'посёлок станции Свирь',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'садовое товарищество Новая Ропша',
#        'садовое товарищество Приладожский', 'садовое товарищество Рахья',
#        'садовое товарищество Садко', 'село Копорье', 'село Никольское',
#        'село Павлово', 'село Паша', 'село Путилово', 'село Рождествено',
#        'село Русско-Высоцкое', 'село Старая Ладога', 'село Шум'],
#       dtype=object)

# %%
len(data.locality_name.sort_values().unique())
# Out:
# 364

# %% [markdown]
# В списке уникальных значений обнаружены повторы из-за разного написания типов населенных пунктов, например, `городской поселок Янино-1`. Помимо этого есть повторы, когда один и тот же населенный пункт указан без типа и с типом, напимер `Кудрово` и `деревня Кудрово`.

# %% [markdown]
# ##### Устранить разные написани типов `поселок` и `посёлок` можно, заменив во всех словах `ё`  на `е` , но при этом все равно останутся повторы типа `Кудрово` и `деревня Кудрово`. Поэтому для устранения повторов в столбце `locality_name` избавимся от типов населенных пунктов, оставив только их названия:

# %%
data.locality_name = data.locality_name.apply(
    lambda title: ' '.join(word for word in title.split(' ') if not(word.islower()))
)

# %% [markdown]
# ##### Вновь изучим уникальные значения в столбце `locality_name`:

# %%
data.locality_name.sort_values().unique()
# Out:
# array(['Агалатово', 'Александровская', 'Алексеевка', 'Аннино', 'Аро',
#        'Барышево', 'Батово', 'Бегуницы', 'Белогорка', 'Белоостров',
#        'Бокситогорск', 'Большая Вруда', 'Большая Ижора',
#        'Большая Пустомержа', 'Большие Колпаны', 'Большое Рейзино',
#        'Большой Сабск', 'Бор', 'Борисова Грива', 'Бугры', 'Будогощь',
#        'Ваганово', 'Важины', 'Вартемяги', 'Вахнова Кара', 'Вещево',
#        'Виллози', 'Вознесенье', 'Возрождение', 'Войсковицы', 'Войскорово',
#        'Володарское', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Вырица', 'Выскатка', 'Высокоключевой', 'Высоцк', 'Гаврилово',
#        'Гарболово', 'Гатчина', 'Гладкое', 'Глажево', 'Глебычево',
#        'Глинка', 'Гончарово', 'Горбунки', 'Гостилицы', 'Громово',
#        'Дзержинского', 'Дружная Горка', 'Дружноселье', 'Дубровка',
#        'Елизаветино', 'Ефимовский', 'Жилгородок', 'Жилпосёлок', 'Житково',
#        'Заводской', 'Заклинье', 'Заневка', 'Запорожское', 'Зеленогорск',
#        'Зимитицы', 'Ивангород', 'Извара', 'Ильичёво', 'Иссад', 'Калитино',
#        'Каложицы', 'Кальтино', 'Каменногорск', 'Камышовка', 'Каськово',
#        'Келози', 'Кивеннапа Север', 'Кикерино', 'Кингисепп',
#        'Кингисеппский', 'Кипень', 'Кириши', 'Кировск', 'Кирпичное',
#        'Кисельня', 'Кобралово', 'Кобринское', 'Колпино', 'Колтуши',
#        'Коммунар', 'Коммунары', 'Кондратьево', 'Копорье', 'Коркино',
#        'Корнево', 'Коробицыно', 'Котельский', 'Котлы', 'Красная Долина',
#        'Красное Село', 'Красносельское', 'Красный Бор', 'Кривко',
#        'Кронштадт', 'Кудрово', 'Кузнечное', 'Кузьмолово', 'Кузьмоловский',
#        'Курковицы', 'Куровицы', 'Куттузи', 'Лаврики', 'Лаголово',
#        'Лампово', 'Лебяжье', 'Левашово', 'Ленинское', 'Лесколово',
#        'Лесная Поляна', 'Лесное', 'Лесогорский', 'Лисий Нос',
#        'Лодейное Поле', 'Ломоносов', 'Лопухинка', 'Луга', 'Лужайка',
#        'Лукаши', 'Лупполово', 'Любань', 'Малая Романовка', 'Малое Верево',
#        'Малое Карлино', 'Малые Колпаны', 'Мануйлово', 'Мга', 'Мельниково',
#        'Меньково', 'Металлострой', 'Мины', 'Мистолово', 'Мичуринское',
#        'Молодцово', 'Молодёжное', 'Морозова', 'Мурино', 'Мыза-Ивановка',
#        'Назия', 'Ненимяки', 'Нижние Осельки', 'Нижняя', 'Низино',
#        'Никольский', 'Никольское', 'Новая Ладога', 'Новая Ропша',
#        'Новогорелово', 'Новое Девяткино', 'Новолисино', 'Новоселье',
#        'Новый Свет', 'Новый Учхоз', 'Нурма', 'Оредеж', 'Оржицы',
#        'Отрадное', 'Павлово', 'Павловск', 'Пансионат Зелёный Бор',
#        'Парголово', 'Парицы', 'Паша', 'Пельгора', 'Пеники',
#        'Первомайское', 'Перово', 'Песочный', 'Петергоф', 'Петро-Славянка',
#        'Петровское', 'Пижма', 'Пикалёво', 'Пикколово', 'Платформа',
#        'Плодовое', 'Плоское', 'Победа', 'Подпорожье', 'Поляны',
#        'Понтонный', 'Почап', 'Починок', 'Приветнинское', 'Пригородный',
#        'Приладожский', 'Приморск', 'Приозерск', 'Пудомяги', 'Пудость',
#        'Пустынка', 'Путилово', 'Пушкин', 'Пушное', 'Пчева', 'Пчевжа',
#        'Рабитицы', 'Разбегаево', 'Раздолье', 'Разметелево', 'Рапполово',
#        'Рахья', 'Реброво', 'Репино', 'Рождествено', 'Романовка',
#        'Ромашки', 'Ропша', 'Рощино', 'Русско', 'Русско-Высоцкое',
#        'Рябово', 'Садко', 'Санкт-Петербург', 'Сапёрное', 'Сапёрный',
#        'Свердлова', 'Светогорск', 'Свирь', 'Свирьстрой', 'Севастьяново',
#        'Селезнёво', 'Сельцо', 'Семиозерье', 'Семрино', 'Серебрянский',
#        'Сертолово', 'Сестрорецк', 'Сиверский', 'Сижно', 'Синявино',
#        'Сланцы', 'Снегирёвка', 'Советский', 'Совхозный', 'Сосново',
#        'Сосновый Бор', 'Старая', 'Старая Ладога', 'Старая Малукса',
#        'Старая Пустошь', 'Старое Хинколово', 'Старополье',
#        'Старосиверская', 'Старые Бегуницы', 'Стеклянный', 'Стрельна',
#        'Суйда', 'Сумино', 'Суоранда', 'Суходолье', 'Счастье',
#        'Сяськелево', 'Сясьстрой', 'Тайцы', 'Тарасово', 'Тельмана',
#        'Терволово', 'Терпилицы', 'Тихвин', 'Тихковицы', 'Тойворово',
#        'Токсово', 'Торковичи', 'Торосово', 'Торошковичи', 'Торфяное',
#        'Тосно', 'Трубников Бор', 'Тёсово-4', 'Углово', 'Ульяновка',
#        'Усть-Ижора', 'Усть-Луга', 'Ушаки', 'Фалилеево', 'Форносово',
#        'Форт Красная Горка', 'Фёдоровское', 'Хапо-Ое', 'Хязельки',
#        'Цвелодубово', 'Цвылёво', 'Чудской Бор', 'Шлиссельбург',
#        'Шпаньково', 'Шугозеро', 'Шум', 'Шушары', 'Щеглово', 'Юкки',
#        'Ялгино', 'Яльгелево', 'Ям-Тесово', 'Янино-1'], dtype=object)

# %%
len(data.locality_name.sort_values().unique())
# Out:
# 305

# %% [markdown]
# Вместо прежних 364 наименований стало 305, избавились от 59 повторов.

# %% [markdown]
# ##### Вновь проверим данные на наличие явных дубликатов:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов необнаружено.

# %% [markdown]
# #### Редкие и выбивающиеся значения

# %% [markdown]
# ##### Проанализируем столбец `last_price` на наличие выбросов:

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце. Предварительно для визуально удобного отображения цен изменим формат отображения вещественных чисел:

# %%
pd.set_option('display.float_format', lambda x: '%.1f'%x)
data.last_price.describe()
# Out:
# count       23565.0
# mean      6540058.3
# std      10910934.7
# min         12190.0
# 25%       3400000.0
# 50%       4646000.0
# 75%       6790000.0
# max     763000000.0
# Name: last_price, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %%
data.boxplot(column='last_price', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Для большей наглядности увеличим масштаб по оси y:

# %%
data.boxplot(column='last_price', grid=True, figsize=(1, 6))
#plt.ylim(0, 4e8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 100 млн являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = data.query('last_price <= 100000000').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `total_area` на наличие выбросов:

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.total_area.describe()
# Out:
# count   23528.0
# mean       59.9
# std        33.5
# min        12.0
# 25%        40.0
# 50%        52.0
# 75%        69.5
# max       590.0
# Name: total_area, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %%
good_data.boxplot(column='total_area', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 400 кв.м. являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = data.query('total_area <= 400').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `rooms` на наличие выбросов:

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.rooms.describe()
# Out:
# count   23542.0
# mean        2.1
# std         1.1
# min         0.0
# 25%         1.0
# 50%         2.0
# 75%         3.0
# max        19.0
# Name: rooms, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %%
good_data.boxplot(column='rooms', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 10 являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.query('rooms <= 10').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `ceiling_height`:

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.ceiling_height.describe()
# Out:
# count   14461.0
# mean        2.8
# std         1.3
# min         1.0
# 25%         2.5
# 50%         2.6
# 75%         2.8
# max       100.0
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %%
good_data.boxplot(column='ceiling_height', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Значения высоты полотка более 40 м  являются выбросом, и их можно отбросить. Сформируем новый набор данных, исключив эти значения, и построим новую диаграмму размаха с увеличенным масштабом по оси  y:

# %%
good_data = good_data.query('ceiling_height < 40 | ceiling_height.isna()').reset_index(drop=True)

# %%
good_data.boxplot(column='ceiling_height', grid=True, figsize=(1, 6))
plt.ylim=(0,40)

# %% [markdown]
# Из диаграммы видно наличие аномалии в диапазоне высот 20-35 м. Вероятно, здесь пропущена точка в вещественных числах. Исправим эти значения:

# %%
def fix_the_ceil(old_ceiling_height):
    if 20 <= old_ceiling_height <= 40:
        return old_ceiling_height / 10
    return old_ceiling_height

# %%
good_data.ceiling_height = good_data.ceiling_height.apply(fix_the_ceil).reset_index(drop=True)

# %% [markdown]
# Вновь построим диаграмму размаха:

# %%
good_data.boxplot(column='ceiling_height', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Значения высоты полотка менее 2 м и более 6 м являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.query('(ceiling_height > 2 & ceiling_height < 6) | ceiling_height.isna()'
                           ).reset_index(drop=True)

# %% [markdown]
# Теперь можем заполнить оставшиеся пропуски в столбце `ceiling_height` медианным значением высоты потолков:

# %%
good_data.ceiling_height = good_data.ceiling_height.fillna(good_data.ceiling_height.median())
good_data.ceiling_height.isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Проанализируем столбец `floors_total`:

# %% [markdown]
# Проверим, есть ли явные аномальные значения количества этажей (нулевые, отрицательные значения, либо меньшие, чем этаж продаваемого объекта недвижимости):

# %%
len(good_data[good_data['floors_total'] <= 0])
# Out:
# 0

# %%
len(good_data[good_data['floor'] > good_data['floors_total']])
# Out:
# 0

# %% [markdown]
# Явные аномалии отсутствуют. Определим самые частые и экстремальные значения в столбце:

# %%
good_data.floors_total.describe()
# Out:
# count   23513.0
# mean       10.7
# std         6.6
# min         1.0
# 25%         5.0
# 50%         9.0
# 75%        16.0
# max        60.0
# Name: floors_total, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.boxplot(column='floors_total', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 40 являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.query('floors_total <= 40').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `floor`:

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.floor.describe()
# Out:
# count   23511.0
# mean        5.9
# std         4.9
# min         1.0
# 25%         2.0
# 50%         4.0
# 75%         8.0
# max        33.0
# Name: floor, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %%
good_data.boxplot(column='floor', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 25 являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.rename(columns = {'floor': 'floors'})

# %%
good_data = good_data.query('floors <= 25').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `living_area`:

# %% [markdown]
# Проверим, есть ли явные аномальные значения жилой площади (отрицательные значения, либо большие, чем общая площадь продаваемого объекта недвижимости):

# %%
len(good_data[good_data['living_area'] < 0])
# Out:
# 0

# %%
len(good_data[good_data['living_area'] > good_data['total_area']])
# Out:
# 0

# %% [markdown]
# Явные аномалии отсутствуют. Определим самые частые и экстремальные значения в столбце:

# %%
good_data.living_area.describe()
# Out:
# count   23471.0
# mean       34.4
# std        21.1
# min         2.0
# 25%        18.7
# 50%        30.0
# 75%        42.2
# max       271.0
# Name: living_area, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.boxplot(column='living_area', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 200 являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.query('living_area <= 200').reset_index(drop=True)

# %% [markdown]
# ##### Проанализируем столбец `kitchen_area`:

# %% [markdown]
# Проверим, есть ли явные аномальные значения площади кухни (отрицательные значения, либо большие, чем общая площадь продаваемого объекта недвижимости):

# %%
len(good_data[good_data['kitchen_area'] < 0])
# Out:
# 0

# %%
len(good_data[good_data['kitchen_area'] > good_data['total_area']])
# Out:
# 0

# %% [markdown]
# Явные аномалии отсутствуют. Определим самые частые и экстремальные значения в столбце:

# %%
good_data.kitchen_area.describe()
# Out:
# count   23452.0
# mean       10.3
# std         5.7
# min         0.0
# 25%         7.0
# 50%         9.0
# 75%        11.8
# max       107.0
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Построим диаграмму размаха для этого столбца

# %% [markdown]
# Определим самые частые и экстремальные значения в столбце:

# %%
good_data.boxplot(column='kitchen_area', grid=True, figsize=(1, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из диаграммы видно, что значения более 80 являются редкими, и их можно отбросить. Сформируем новый набор данных, исключив эти значения:

# %%
good_data = good_data.query('kitchen_area <= 80').reset_index(drop=True)

# %% [markdown]
# ##### Остальные столбцы либо не несут важной смысловой нагрузки для последующего анализа, либо распределение их значений по первичным диаграммам близко к нормальному - поэтому анализ этих столбцов на аномалии не требуется.

# %% [markdown]
# ### Посчитаем и добавим в таблицу новые столбцы

# %% [markdown]
# #### Цена одного квадратного метра:

# %%
good_data['price_for_meter'] = good_data.last_price / good_data.total_area

# %% [markdown]
# #### День недели публикации объявления:

# %%
good_data['exposition_weekday'] = good_data.first_day_exposition.dt.weekday

# %% [markdown]
# #### Месяц публикации объявления:

# %% [markdown]
# Для анализа месяцев публикации объявлений (в целом по всем годам) создадим столбец `exposition_month`:

# %%
good_data['exposition_month'] = good_data.first_day_exposition.dt.month
good_data['exposition_month'].head()
# Out:
# 0     3
# 1    12
# 2     8
# 3     7
# 4     6
# Name: exposition_month, dtype: int64

# %% [markdown]
# Для анализа месяцев в каждом конкретном году создадим столбец `exposition_month_of_the_year`:

# %%
good_data['exposition_month_of_the_year'] = good_data.first_day_exposition.astype('datetime64[M]')
good_data['exposition_month_of_the_year'].head()
# Out:
# 0   2019-03-01
# 1   2018-12-01
# 2   2015-08-01
# 3   2015-07-01
# 4   2018-06-01
# Name: exposition_month_of_the_year, dtype: datetime64[ns]

# %% [markdown]
# #### Год публикации объявления:

# %%
good_data['exposition_year'] = good_data.first_day_exposition.dt.year

# %% [markdown]
# #### Тип этажа квартиры:

# %%
def get_floor_type(row):
    if row['floors'] == 1:
        return "первый"
    elif row['floors'] == row['floors_total']:
        return "последний"
    else:
        return "другой"

# %%
good_data['floor_type'] = good_data.apply(get_floor_type, axis=1)

# %% [markdown]
# #### Расстояние до центра города в километрах:

# %%
good_data['km_to_city_center'] = round(good_data.cityCenters_nearest / 1000)

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучим параметры объектов недвижимости:

# %% [markdown]
# ##### Данные по общей площади:

# %%
good_data['total_area'].hist(bins=30, range=(0,150),legend='total_area')
plt.show()

# %% [markdown]
# В наборе данных преобладают объекты общей площадью 40-45 кв.м.

# %% [markdown]
# ##### Данные по жилой площади:

# %%
good_data['living_area'].hist(bins=30, range=(0,150),legend='living_area')
plt.show()

# %% [markdown]
# Среди продаваемых объектов недвижимости больше всего объектов с жилой площадью 15-20 кв.м., но есть и объекты с жилой площадью менее 10 кв.м.

# %% [markdown]
# ##### Данные по  площади кухни:

# %%
good_data['kitchen_area'].hist(bins=30, range=(0,50),legend='kitchen_area')
plt.show()

# %% [markdown]
# Наиболее часто встречаемая площадь кухонь 5-12 кв. м. (чаще всего около 8), при этом присутствуют кухни с площадью менее 5 кв.м и более 40.

# %% [markdown]
# ##### Данные по цене объекта:

# %%
good_data['last_price'].hist(bins=30, range=(0,3e7), legend='last_price')
plt.show()

# %% [markdown]
# Наиболее частая цена объекта 3,5-5 млн.руб.

# %% [markdown]
# ##### Данные по количеству комнат:

# %%
good_data['rooms'].hist(bins=8, range=(0,8),legend='rooms')
plt.show()

# %% [markdown]
# Больше всего проедается квартир с количеством комнат 1 и 2, что логично и в целом соответствует рынку недвижимости.

# %% [markdown]
# ##### Данные по высоте потолков:

# %%
good_data['ceiling_height'].hist(bins=30, range=(2.25,4),legend='ceiling_height')
plt.show()

# %% [markdown]
# Наиболее часто встречающиеся высоты потолков 2,5 и 2,6 м что соответствуем двум самым полпулярным классам объектом недвижимости.

# %% [markdown]
# ##### Данные по этажу квартиры:

# %%
good_data['floors'].hist(bins=30, range=(0,30),legend='floor')
plt.show()

# %% [markdown]
# Судя по гистограмме, чаще всего продавались объекты высотой до 6 этажа.

# %% [markdown]
# ##### Данные по типу этажа квартиры:

# %%
good_data['floor_type'].hist(bins=3,legend='floor_type')
plt.show()

# %% [markdown]
# Большая часть продаваемых квартир расположена ни на первых ни на последних этажах, первые и последние этаже продаются реже.

# %% [markdown]
# ##### Данные по общему количеству этажей в доме:

# %%
good_data['floors_total'].hist(bins=30,range=(0,30),legend='floors_total')
plt.show()

# %% [markdown]
# Наибольшее число квартир продавалось в 5-этажных домах и 9-этажных.

# %% [markdown]
# ##### Данные по расстоянию до центра города в метрах:

# %%
good_data['cityCenters_nearest'].hist(bins=30, range=(0,60000), legend='cityCenters_nearest')
plt.show()

# %% [markdown]
# Чаще всего продавались объекты, удаленные от центра на 12-16 км.

# %% [markdown]
# ##### Данные по расстоянию до ближайшего аэропорта:

# %%
good_data['airports_nearest'].hist(bins=30, range=(0,80000), legend='airports_nearest')
plt.show()

# %% [markdown]
# Удаленность объектов недвижимости от аэропортов сильно разбросана, но все же преобладают объекты с расстоянием до аэропорта 12-14 км.

# %% [markdown]
# ##### Данные по расстоянию до ближайшего парка:

# %%
good_data['parks_nearest'].hist(bins=30, range=(0,1500),legend='parks_nearest')
plt.show()

# %% [markdown]
# Самое частое расстояние до парка среди продаваемых объектов составляет 450 м.

# %% [markdown]
# ##### Данные по дню публикации объявлений:

# %%
good_data['exposition_weekday'].hist(bins=6)
plt.show()

# %% [markdown]
# В целом размещение объявлений по дням недели происходило примерно равномерно с небольшим преобладанием в четверг.

# %% [markdown]
# ##### Данные по месяцу публикации объявлений:

# %%
good_data['exposition_month'].hist(bins=11)
plt.show()

# %% [markdown]
# Больше всего объявления о продаже опубликованов последний месяц года.

# %% [markdown]
# **Вывод по п. 4.1:**
# Проанализоровав данные таблицы, сделали вывод о наиболее продаваемом объекте недвижимости:
#     это 1-2 комнатная квартира на 2-м этаже 5-этажного дома общей площадью около 45 кв.м. с жилой площадью 15-20 кв.м. и площадью кухни около 8 кв.м., стоимостью 3,5-5 млн.руб. и высотой потолков 2,6 м., удаленная от центра на 12-16 км., от парка на 450 м и от аэропорта на 12-14 км. В конце года происходил резкий рост количества объявления о продаже.

# %% [markdown]
# #### Анализ скорости продажи квартир

# %% [markdown]
# ##### Построим гистограмму по данным столбца `days_exposition`, показывающего сколько дней было размещено объявление:

# %%
good_data['days_exposition'].hist(bins=11)
plt.show()

# %% [markdown]
# Для более наглядного отображения изменим масштаб отображения гистограммы и увеличим количество корзин:

# %%
good_data['days_exposition'].hist(bins=200, range=(0, 200))
plt.show()

# %% [markdown]
# На диаграмме обнаружились интересные аномалии, найдем их зачения:

# %%
good_data['days_exposition'].value_counts().head(10)
# Out:
# 45.0    875
# 60.0    538
# 7.0     233
# 30.0    208
# 90.0    199
# 4.0     174
# 3.0     156
# 5.0     151
# 14.0    143
# 9.0     141
# Name: days_exposition, dtype: int64

# %% [markdown]
# Оказывается, чаще всего объекты продавались на 45-й и 60-й день после подачи объявлений.

# %% [markdown]
# ##### Посчитаем среднее и медиану по данным столбца `days_exposition`:

# %%
good_data['days_exposition'].describe()
# Out:
# count   20298.0
# mean      180.6
# std       219.6
# min         1.0
# 25%        45.0
# 50%        95.0
# 75%       231.0
# max      1580.0
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее время продажи квартиры составляет 180 дней. Медианное значение составляет 95 дней, что сильно отличается от среднего, такие продажи можно назвать быстрыми. Чаще всего объекты продавались на 45-й и 60-й день после подачи объявлений. При этом в наборе данных присутствуют необычно долгие продажи в течение 4-х лет и более.

# %% [markdown]
# ##### Для более детальной оценки скорости продажи можно оценить ее в зависмости от других факторов, например, от месяца подачи объявления:

# %%
good_data.groupby('exposition_month')['days_exposition'].mean().plot.bar()
plt.show()

# %% [markdown]
# Таким образом мы обнаружили, что быстрее всего продавались квартиры, размещенные в объявлениях в ноябре, а медленнее всего - размещенные в мае.

# %% [markdown]
# #### Изучим факторы, влияющие на общую (полную) стоимость объекта

# %% [markdown]
# ##### Проанализируем зависимость цены от общей площади объекта:

# %% [markdown]
# Построим диаграмму рассеяния:

# %%
seaborn.scatterplot(x='total_area', y='last_price', data=good_data)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# Построим диаграмму рассеяния с линией регрессии:

# %%
seaborn.regplot(
    x='total_area', 
    y='last_price', 
    data=good_data, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"})
plt.xlabel(
    'Общая площадь')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Из диаграммы видно, что с ростом общей площади растет и цена, при этом также увеличивается разброс цен на объекты одинаковой площади.

# %% [markdown]
# Для оценки корреляции рассчитаем коэффициент Пирсона:

# %%
round(good_data['total_area'].corr(good_data['last_price']), 2)
# Out:
# 0.68

# %% [markdown]
# ##### Проанализируем зависимость цены от жилой площади объекта:

# %% [markdown]
# Построим диаграмму рассеяния с линией регрессии:

# %%
seaborn.regplot(
    x='living_area', 
    y='last_price', 
    data=good_data, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"})
plt.xlabel(
    'Жилая площадь')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для оценки корреляции рассчитаем коэффициент Пирсона:

# %%
round(good_data['living_area'].corr(good_data['last_price']), 2)
# Out:
# 0.6

# %% [markdown]
# Из диаграммы видно, что с ростом жилой площади растет и цена, при этом также увеличивается разброс цен на объекты с одинаковой жилой площадью. Однако рассчитанный коэффциент корреляции ниже, чем аналогичный коэффициент для общей площади.

# %% [markdown]
# ##### Проанализируем зависимость цены от площади кухни объекта:

# %% [markdown]
# Построим диаграмму рассеяния с линией регрессии:

# %%
seaborn.regplot(
    x='kitchen_area', 
    y='last_price', 
    data=good_data, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"})
plt.xlabel(
    'Площадь кухни')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для оценки корреляции рассчитаем коэффициент Пирсона:

# %%
round(good_data['kitchen_area'].corr(good_data['last_price']), 2)
# Out:
# 0.54

# %% [markdown]
# Из диаграммы видно, что с ростом площади кухни растет и цена, однако рассчитанный коэффциент корреляции ниже, чем аналогичный коэффициент для общей площади.

# %% [markdown]
# ##### Проанализируем зависимость цены от количества комнат объекта:

# %% [markdown]
# Построим диаграмму рассеяния с линией регрессии:

# %%
seaborn.regplot(
    x='rooms', 
    y='last_price', 
    data=good_data, scatter_kws={"color": "lightblue"}, line_kws={"color": "blue"})
plt.xlabel(
    'Количество комнат')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для оценки корреляции рассчитаем коэффициент Пирсона:

# %%
round(good_data['rooms'].corr(good_data['last_price']), 2)
# Out:
# 0.4

# %% [markdown]
# Из диаграммы видно, что с ростом количества комнат растет и цена, однако рассчитанный коэффциент корреляции ниже, чем аналогичный коэффициент для общей площади. На объекты с количеством комнат равным 5 наблюдается наибольший разброс цен.

# %% [markdown]
# ##### Проанализируем зависимость цены от этажа, на котором расположена квартира (первый, последний, другой):

# %% [markdown]
# Построим гистограмму:

# %%
seaborn.barplot(
    x='floor_type', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'Этаж')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Из гистограммы видно, что самая низкая цена у квартир на первом этаже, а выше всего цены на квартиры, находящиеся ни на первом, ни на последнем этаже.

# %% [markdown]
# ##### Проанализируем зависимость цены от дня недели размещения объявления:

# %% [markdown]
# Построим гистограмму:

# %%
seaborn.barplot(
    x='exposition_weekday', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'День недели')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для большей наглядности построим точечную диаграмму:

# %%
seaborn.pointplot(
    x='exposition_weekday', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'День недели')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Из диаграммы видно, что дороже всего продавались квартиры, размещенные в объявлениях по четвергам.

# %% [markdown]
# ##### Проанализируем зависимость цены от месца размещения объявления:

# %% [markdown]
# Построим гистограмму:

# %%
seaborn.barplot(
    x='exposition_month', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'Месяц')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для большей наглядности построим точечную диаграмму:

# %%
seaborn.pointplot(
    x='exposition_month', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'Месяц')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Из диаграммы видно, что дешевле всего продавались квартиры, размещенные в объявлениях в октябре, а дороже всего  - размещенные в апреле и декабре.

# %% [markdown]
# ##### Проанализируем зависимость цены от года размещения объявления:

# %% [markdown]
# Построим гистограмму:

# %%
seaborn.barplot(
    x='exposition_year', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'Год')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Для большей наглядности построим точечную диаграмму:

# %%
seaborn.pointplot(
    x='exposition_year', 
    y='last_price', 
    data=good_data)
plt.xlabel(
    'Год')
plt.ylabel(
    'Стоимость')
plt.show()

# %% [markdown]
# Из диаграммы видно, что с 2014 года цены на квартиры падали, в 2018 году была самая низкая цена продаж, после чего цены вновь начали расти. Но на уменьшение стоимости квартир могло повлиять уменьшение их площади. Проверим это предположение, проанализировав зависимость площади и цены квадратного метра от года размещения объявления:

# %%
seaborn.pointplot(
    x='exposition_year', 
    y='total_area', 
    data=good_data)
plt.xlabel(
    'Год')
plt.ylabel(
    'Общая площадь квартиры')
plt.show()

# %%
seaborn.pointplot(
    x='exposition_year', 
    y='price_for_meter', 
    data=good_data)
plt.xlabel(
    'Год')
plt.ylabel(
    'Стоимость кв.метра')
plt.show()

# %% [markdown]
# Действительно, в 2018 г были минимальные площади продаваемых квартир, что обусловило и минимальные цены на объекты недвижимости. Проверив динамику стоимости квадратного метра, обнаружили, что в 2017- 2018 гг стоимость квадратного метра стала минимальной, после чего, вероятно, стало невыгодно продавать квартиры с большой площадью, и площадь продаваемых объектов в 2018 году упала до минимума.

# %% [markdown]
# #### Проанализируем цену одного квадратного метра

# %% [markdown]
# ##### Посчитаем медианную цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений:

# %%
median_prices = good_data.groupby('locality_name')['price_for_meter']\
                        .agg(['count','median'])\
                        .sort_values(by='count', ascending=False).head(10)
median_prices
# Out:
#                  count   median
# locality_name
# Санкт-Петербург  15574 104749.3
# Мурино             575  86272.5
# Кудрово            469  95588.2
# Шушары             439  76829.3
# Всеволожск         397  65789.5
# Пушкин             368  99993.6
# Колпино            338  74723.7
# Парголово          313  91642.9
# Гатчина            307  67796.6
# Выборг             235  58307.7

# %% [markdown]
# ##### Населенный пункт с минимальной стоимостью квадратного метра (среди 10-ти н.п. с наибольшим количеством объявлений):

# %%
median_prices[median_prices['median'] == median_prices['median'].min()]
# Out:
#                count  median
# locality_name
# Выборг           235 58307.7

# %% [markdown]
# ##### Населенный пункт с максимальной стоимостью квадратного метра (среди 10-ти н.п. с наибольшим количеством объявлений):

# %%
median_prices[median_prices['median'] == median_prices['median'].max()]
# Out:
#                  count   median
# locality_name
# Санкт-Петербург  15574 104749.3

# %% [markdown]
# ##### Выделим цветом максимальную и минимальную стоимости квадратного метра среди 10 населенных пунктов с наибольшим количесвом объявлений, построив температурный график (синий - минимальный, красный - максимальный):

# %%
pd.DataFrame(median_prices['median'].to_frame(name='Цена кв.м.')).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_f7321_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f7321_row1_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f7321_row2_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_f7321_row3_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f7321_row4_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f7321_row5_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_f7321_row6_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f7321_row7_col0 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_f7321_row8_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f7321_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7321">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7321_level0_col0" class="col_heading level0 col0" >Цена кв.м.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >locality_name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7321_level0_row0" class="row_heading level0 row0" >Санкт-Петербург</th>
#       <td id="T_f7321_row0_col0" class="data row0 col0" >104749.301676</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row1" class="row_heading level0 row1" >Мурино</th>
#       <td id="T_f7321_row1_col0" class="data row1 col0" >86272.475795</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row2" class="row_heading level0 row2" >Кудрово</th>
#       <td id="T_f7321_row2_col0" class="data row2 col0" >95588.235294</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row3" class="row_heading level0 row3" >Шушары</th>
#       <td id="T_f7321_row3_col0" class="data row3 col0" >76829.268293</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row4" class="row_heading level0 row4" >Всеволожск</th>
#       <td id="T_f7321_row4_col0" class="data row4 col0" >65789.473684</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row5" class="row_heading level0 row5" >Пушкин</th>
#       <td id="T_f7321_row5_col0" class="data row5 col0" >99993.589744</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row6" class="row_heading level0 row6" >Колпино</th>
#       <td id="T_f7321_row6_col0" class="data row6 col0" >74723.748474</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row7" class="row_heading level0 row7" >Парголово</th>
#       <td id="T_f7321_row7_col0" class="data row7 col0" >91642.857143</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row8" class="row_heading level0 row8" >Гатчина</th>
#       <td id="T_f7321_row8_col0" class="data row8 col0" >67796.610169</td>
#     </tr>
#     <tr>
#       <th id="T_f7321_level0_row9" class="row_heading level0 row9" >Выборг</th>
#       <td id="T_f7321_row9_col0" class="data row9 col0" >58307.692308</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Вывод по п. 4.4:**
# Среди 10 населенных пунктов с наибольшим количеством объявлений максимальная стоимость квадратного метра наблюдается в Санкт-Петербурге, минимальная - в Выборге.

# %% [markdown]
# #### Проанализируем стоимость объектов в зависимости от расстояния до центра в километрах:

# %%
prices_km_to_center = good_data.query('locality_name == "Санкт-Петербург"')\
        .pivot_table(index='km_to_city_center', values='price_for_meter')
prices_km_to_center
# Out:
#                    price_for_meter
# km_to_city_center
# 0.0                       245833.5
# 1.0                       177140.7
# 2.0                       155362.3
# 3.0                       121133.0
# 4.0                       130266.3
# 5.0                       138927.1
# 6.0                       147940.3
# 7.0                       155687.1
# 8.0                       124340.9
# 9.0                       113159.4
# 10.0                      112658.8
# 11.0                      108388.3
# 12.0                      107481.1
# 13.0                      108105.1
# 14.0                      104201.2
# 15.0                      104287.9
# 16.0                      100542.6
# 17.0                       97008.3
# 18.0                       96362.3
# 19.0                       98658.4
# 20.0                      100159.8
# 21.0                       94469.6
# 22.0                       91330.4
# 23.0                       91828.5
# 24.0                       85736.9
# 25.0                       91531.4
# 26.0                       87798.9
# 27.0                      132115.7
# 28.0                       81161.9
# 29.0                       72953.4

# %% [markdown]
# Построим соответствующий график:

# %%
prices_km_to_center.plot(grid=True, title = 'Cтоимость "удаления" от центра города')
plt.show()

# %% [markdown]
# **Вывод по п. 4.5:**
# В целом с удалением от центра Санкт-Петербурга стоимость квадратного метра уменьшается. Однако на удаленности 7 км и 27 км от центра наблюдается рост цен квадратного метра, это может быть связано с нахождением там КАД или элитных жилых районов.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Для исследования объявлений о продаже квартир мы проанализировали данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет.
# До предобработки объем данных составлял 23699 строк, который в процессе обработки сократился  до 23449 строк. В процессе обработки обнаружили наибольшее количество пропусков в столбце `is_apartment`.Проанализировав строки с пропусками, сделали следующие предположения: пропуски в столбце is_apartment, вероятно, связаны с тем, что данные объекты недвижимости не являются апартаментами, такие пропуски заменили на False. Пропуски в графе balcony, вероятно, связаны с тем, что в данных объектах недвижимости нет балконов, их заменили нулями. Пропуски в графе  «Жилая площадь» заполнили произведениями известных величин общей площади на коэффициенты долей жилой площади в общей в зависимости от количества комнат. Пропуски в графе «Площадь кухни» заполнили минимальными значениями из двух рассчитанных площадей кухонь (рассчитанной из условия, что сумма площади кухни и жилой площади не должна превышать 0,9 от общей площади и рассчитанной как известных величин общей площади на коэффициент доли площади кухни в общей площади. Пропуски высоты потолков заполнили медианным значением. Пропуски в графах «Название н.п.» и «Общее кол-во этажей» отбросили, т.к. они составляли малую долю в общих данных. Далее изменили типы данных в столбцах first_day_exposition ,floors_total, balcony, parks_around3000, ponds_around3000, days_exposition  - для удобства последующего анализа. Далее выполнили поиск дубликатов и заменили разные написания названий одних и тех же населенных пунктов - на единые. Проанализировав редкие и выбивающиеся значения отбросили данные о квартирах стоимостью более 100 млн общей площадью более 400 кв.м. с числом комнат более 10, высотой потолков более 6 м. и менее 2 м, располагающиеся выше 25 этажа, в домах высотой более 40 этажей, с жилой площадью более 200 кв.м. И площадью кухни более 80 кв.м.
# Затем посчитали и добавили в таблицу данные о стоимости одного квадратного метра, дне недели, месяце и годе публикации объявления, типе этажа квартиры и расстоянии до центра города в км.
# Далее провели исследовательский анализ данных:
# 1. Изучив параметры объектов недвижимости, сделали вывод о наиболее продаваемом объекте недвижимости: это 1-2 комнатная квартира на 2-м этаже 5-этажного дома общей площадью 40-45 кв.м. с жилой площадью 15-20 кв.м. и площадью кухни около 8 кв.м., стоимостью 3,5-5 млн.руб. и высотой потолков 2,6 м., удаленная от центра на 12-16 км., от парка на 450 м и от аэропорта на 12-14 км. В конце года происходил резкий рост количества объявления о продаже.
# 2. Проведя анализ скорости продажи квартир, обнаружили, что среднее время продажи квартиры составляет 180 дней. Медианное значение составляет 95 дней, что сильно отличается от среднего. Чаще всего объекты продавались на 45-й и 60-й день после подачи объявлений. При этом в наборе данных присутствуют необычно долгие продажи в течение 4-х лет и более. Также обнаружили, что быстрее всего продавались квартиры, размещенные в объявлениях в ноябре, а медленнее всего - размещенные в мае.
# 3.  Изучив факторы, влияющие на стоимость объекта, выяснили что больше всего на стоимость влияет полная площадь объектов. При этом самая низкая цена у квартир на первом этаже, а выше всего цены на квартиры, находящиеся ни на первом, ни на последнем этаже. Также дороже всего продавались квартиры, размещенные в объявлениях по четвергам в апреле и декабре, а дешевле всего - в октябре. Кроме того выяснили, что Из диаграммы видно, что с 2014 года цены на квартиры падали, в 2018 году была самая низкая цена продаж, после чего цены вновь начали расти. Но падение стоимости квартир было обусловлено тем, что в 2018 г. были минимальные площади продаваемых объектов. Проверив динамику стоимости квадратного метра, обнаружили, что в 2017- 2018 гг стоимость квадратного метра стала минимальной, после чего, вероятно, стало невыгодно продавать квартиры с большой площадью, и площадь продаваемых объектов в 2018 году упала до минимума.
# 4.  Проанализировав цену одного квадратного метра, выяснили, что среди 10 населенных пунктов с наибольшим количеством объявлений максимальная стоимость квадратного метра наблюдается в Санкт-Петербурге, минимальная - в Выборге.
# 5.  Проанализировав стоимость объектов в зависимости от расстояния до центра в километрах убедились, что в целом с удалением от центра Санкт-Петербурга стоимость квадратного метра уменьшается. Однако на удаленности 7 км и 27 км от центра наблюдается рост цен квадратного метра, это может быть связано с нахождением там КАД или элитных жилых районов.
